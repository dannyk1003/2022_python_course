# %%
import pandas as pd
df = pd.read_json('nobel_winners.json')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         1052 non-null   object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1044 non-null   object
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %%
df.describe(include = 'object')
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                   name place_of_birth place_of_death  \
# count             1052           1044           1044
# unique             998            735            410
# top     César Milstein
# freq                 2             29            409
#
# ...

# %%
df.describe(include = 'all')
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
# mean       NaN                     NaN            NaN              NaN
# std        NaN                     NaN            NaN              NaN
# min        NaN                     NaN            NaN              NaN
# 25%        NaN                     NaN            NaN              NaN
# 50%        NaN                     NaN            NaN              NaN
# 75%        NaN                     NaN            NaN              NaN
# max        NaN                     NaN            NaN              NaN
#
#        date_of_death gender                                         link  \
# ...

# %%
df.columns
# Out:
# Index(['born_in', 'category', 'country', 'date_of_birth', 'date_of_death',
#        'gender', 'link', 'name', 'place_of_birth', 'place_of_death', 'text',
#        'year'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1052, step=1)

# %%
df
# Out:
#                      born_in                category    country  \
# 0                             Physiology or Medicine  Argentina
# 1     Bosnia and Herzegovina              Literature
# 2     Bosnia and Herzegovina               Chemistry
# 3                                              Peace    Belgium
# 4                                              Peace    Belgium
# ...                      ...                     ...        ...
# 1047                                         Physics  Australia
# 1048                                           Peace  Argentina
# 1049                          Physiology or Medicine  Argentina
# 1050                                       Chemistry  Argentina
# 1051                                           Peace  Argentina
#
#           date_of_birth   date_of_death gender  \
# 0        8 October 1927   24 March 2002   male
# 1        9 October 1892   13 March 1975   male
# 2         July 23, 1906      1998-01-07   male
# ...

# %%
df.set_index('name')
#df.set_index('name', inplace = 'True') 儲存異動
df = df.set_index('name') #儲存異動
df
# Out:
#                                                 born_in  \
# name
# César Milstein
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International
# Auguste Beernaert
# ...                                                 ...
# Brian P. Schmidt
# Carlos Saavedra Lamas
# Bernardo Houssay
# Luis Federico Leloir
# Adolfo Pérez Esquivel
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature
# Vladimir Prelog *                             Chemistry
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
# ...                                                 ...        ...
# Brian P. Schmidt                                Physics  Australia
# ...

# %%
df.loc[['César Milstein', 'Auguste Beernaert'], ['category', 'country']]
#select 'category', 'country' from nobels where name in ('César Milstein', 'Auguste Beernaert')
# Out:
#                                  category         country
# name
# César Milstein     Physiology or Medicine       Argentina
# César Milstein     Physiology or Medicine  United Kingdom
# Auguste Beernaert                   Peace         Belgium

# %%
df.iloc[[0, 4],[1, 2]]
# Out:
#                                  category    country
# name
# César Milstein     Physiology or Medicine  Argentina
# Auguste Beernaert                   Peace    Belgium

# %%
df = df.reset_index()
df
# Out:
#                                  name                 born_in  \
# 0                      César Milstein
# 1                        Ivo Andric *  Bosnia and Herzegovina
# 2                   Vladimir Prelog *  Bosnia and Herzegovina
# 3     Institut de Droit International
# 4                   Auguste Beernaert
# ...                               ...                     ...
# 1047                 Brian P. Schmidt
# 1048            Carlos Saavedra Lamas
# 1049                 Bernardo Houssay
# 1050             Luis Federico Leloir
# 1051            Adolfo Pérez Esquivel
#
#                     category    country      date_of_birth   date_of_death  \
# 0     Physiology or Medicine  Argentina     8 October 1927   24 March 2002
# 1                 Literature                9 October 1892   13 March 1975
# 2                  Chemistry                 July 23, 1906      1998-01-07
# 3                      Peace    Belgium               None            None
# ...

# %%
df['year']
# Out:
# 0       1984
# 1       1961
# 2       1975
# 3       1904
# 4       1909
#         ...
# 1047    2011
# 1048    1936
# 1049    1947
# 1050    1970
# 1051    1980
# Name: year, Length: 1052, dtype: int64

# %%
df.year
# Out:
# 0       1984
# 1       1961
# 2       1975
# 3       1904
# 4       1909
#         ...
# 1047    2011
# 1048    1936
# 1049    1947
# 1050    1970
# 1051    1980
# Name: year, Length: 1052, dtype: int64

# %%
df.loc[:, 'year']
# Out:
# 0       1984
# 1       1961
# 2       1975
# 3       1904
# 4       1909
#         ...
# 1047    2011
# 1048    1936
# 1049    1947
# 1050    1970
# 1051    1980
# Name: year, Length: 1052, dtype: int64

# %%
df[['name', 'category', 'year']]
# Out:
#                                  name                category  year
# 0                      César Milstein  Physiology or Medicine  1984
# 1                        Ivo Andric *              Literature  1961
# 2                   Vladimir Prelog *               Chemistry  1975
# 3     Institut de Droit International                   Peace  1904
# 4                   Auguste Beernaert                   Peace  1909
# ...                               ...                     ...   ...
# 1047                 Brian P. Schmidt                 Physics  2011
# 1048            Carlos Saavedra Lamas                   Peace  1936
# 1049                 Bernardo Houssay  Physiology or Medicine  1947
# 1050             Luis Federico Leloir               Chemistry  1970
# 1051            Adolfo Pérez Esquivel                   Peace  1980
#
# [1052 rows x 3 columns]

# %%
mask = df['year'] > 2000
df[mask].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 13 to 1047
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            202 non-null    object
#  1   born_in         202 non-null    object
#  2   category        202 non-null    object
#  3   country         202 non-null    object
#  4   date_of_birth   201 non-null    object
#  5   date_of_death   201 non-null    object
#  6   gender          200 non-null    object
#  7   link            202 non-null    object
#  8   place_of_birth  201 non-null    object
#  9   place_of_death  201 non-null    object
#  10  text            202 non-null    object
#  11  year            202 non-null    int64
# dtypes: int64(1), object(11)
# memory usage: 20.5+ KB

# %%
df[mask][['name', 'category', 'year']].describe(include = 'object')
# Out:
#                   name category
# count              202      202
# unique             185        6
# top     Leonid Hurwicz  Physics
# freq                 2       48

# %%
df['born_in'][df['born_in'] == '']
# Out:
# 0
# 3
# 4
# 5
# 6
#        ..
# 1047
# 1048
# 1049
# 1050
# 1051
# Name: born_in, Length: 910, dtype: object

# %%
df_born_in = df[df['born_in'] != '']
df_born_in
# Out:
#                           name                 born_in  \
# 1                 Ivo Andric *  Bosnia and Herzegovina
# 2            Vladimir Prelog *  Bosnia and Herzegovina
# 14             Simon Kuznets *                 Belarus
# 15            Menachem Begin *                 Belarus
# 16              Shimon Peres *                 Belarus
# ...                        ...                     ...
# 1034          Martin Karplus *                 Austria
# 1035  William Lawrence Bragg *               Australia
# 1039  Aleksandr M. Prokhorov *               Australia
# 1041   John Warcup Cornforth *               Australia
# 1046  Elizabeth H. Blackburn *               Australia
#
#                     category country     date_of_birth    date_of_death  \
# 1                 Literature            9 October 1892    13 March 1975
# 2                  Chemistry             July 23, 1906       1998-01-07
# 14                 Economics            April 30, 1901     July 8, 1985
# ...

# %%
import numpy as np
df['born_in'] = df['born_in'].replace('', np.nan)
df['born_in']
# Out:
# 0                          NaN
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3                          NaN
# 4                          NaN
#                  ...
# 1047                       NaN
# 1048                       NaN
# 1049                       NaN
# 1050                       NaN
# 1051                       NaN
# Name: born_in, Length: 1052, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1052 non-null   object
#  1   born_in         142 non-null    object
#  2   category        1052 non-null   object
#  3   country         1052 non-null   object
#  4   date_of_birth   1044 non-null   object
#  5   date_of_death   1044 non-null   object
#  6   gender          1040 non-null   object
#  7   link            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %%
df = df.drop('born_in', axis = 1)
df
# Out:
#                                  name                category    country  \
# 0                      César Milstein  Physiology or Medicine  Argentina
# 1                        Ivo Andric *              Literature
# 2                   Vladimir Prelog *               Chemistry
# 3     Institut de Droit International                   Peace    Belgium
# 4                   Auguste Beernaert                   Peace    Belgium
# ...                               ...                     ...        ...
# 1047                 Brian P. Schmidt                 Physics  Australia
# 1048            Carlos Saavedra Lamas                   Peace  Argentina
# 1049                 Bernardo Houssay  Physiology or Medicine  Argentina
# 1050             Luis Federico Leloir               Chemistry  Argentina
# 1051            Adolfo Pérez Esquivel                   Peace  Argentina
#
#           date_of_birth   date_of_death gender  \
# 0        8 October 1927   24 March 2002   male
# ...

# %%
df = df.replace('', np.nan)
df
# Out:
#                                  name                category    country  \
# 0                      César Milstein  Physiology or Medicine  Argentina
# 1                        Ivo Andric *              Literature        NaN
# 2                   Vladimir Prelog *               Chemistry        NaN
# 3     Institut de Droit International                   Peace    Belgium
# 4                   Auguste Beernaert                   Peace    Belgium
# ...                               ...                     ...        ...
# 1047                 Brian P. Schmidt                 Physics  Australia
# 1048            Carlos Saavedra Lamas                   Peace  Argentina
# 1049                 Bernardo Houssay  Physiology or Medicine  Argentina
# 1050             Luis Federico Leloir               Chemistry  Argentina
# 1051            Adolfo Pérez Esquivel                   Peace  Argentina
#
#           date_of_birth   date_of_death gender  \
# ...

# %%
df[df['name'].str.contains('\*')]
# Out:
# Empty DataFrame
# Columns: [name, category, country, date_of_birth, date_of_death, gender, link, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df['name'] = df['name'].str.replace('*', '')
df['name'] = df['name'].str.strip()
df['name']

# #df['born_in'].replace('',np.nan)  #整個欄位符合條件就完整取代
# df['name'] = df['name'].str.replace('*','')    #部分文字符合條件就取代部分文字
# df['name'] = df['name'].str.strip()
# df['name']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13276\336876187.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['name'] = df['name'].str.replace('*', '')
# 0                        César Milstein
# 1                            Ivo Andric
# 2                       Vladimir Prelog
# 3       Institut de Droit International
# 4                     Auguste Beernaert
#                      ...
# 1047                   Brian P. Schmidt
# 1048              Carlos Saavedra Lamas
# 1049                   Bernardo Houssay
# 1050               Luis Federico Leloir
# 1051              Adolfo Pérez Esquivel
# Name: name, Length: 1052, dtype: object

# %%
df[df.duplicated(['name', 'category'])]
# Out:
#                         name    category         country      date_of_birth  \
# 90            Menachem Begin       Peace          Israel     16 August 1913
# 91              Shimon Peres       Peace          Israel      2 August 1923
# 109          Wilhelm Ostwald   Chemistry             NaN         1853-09-02
# 121               Aaron Klug   Chemistry    South Africa     11 August 1926
# 131               Aaron Klug   Chemistry  United Kingdom     11 August 1926
# ...                      ...         ...             ...                ...
# 1039  Aleksandr M. Prokhorov     Physics             NaN       11 July 1916
# 1040           Patrick White  Literature       Australia        28 May 1912
# 1042           John Harsanyi   Economics       Australia       May 29, 1920
# 1047        Brian P. Schmidt     Physics       Australia  February 24, 1967
# 1050    Luis Federico Leloir   Chemistry       Argentina           1906-9-6
#
#           date_of_death gender  \
# ...

# %%
sorted(list(df[df.duplicated('name')]['name']))
# Out:
# ['Aaron Klug',
#  'Aaron Klug',
#  'Alan MacDiarmid',
#  'Albert Einstein',
#  'Albert Schweitzer',
#  'Aleksandr M. Prokhorov',
#  'Alexei A. Abrikosov',
#  'Alfred Werner',
#  'Allan M. Cormack',
#  'Andre Geim',
#  'Andrew Schally',
#  'Anthony J. Leggett',
#  'Arieh Warshel',
#  'Arno Penzias',
#  'Avram Hershko',
#  'Baruj Benacerraf',
#  'Bernard Katz',
#  'Bertha von Suttner',
#  'Betty Williams',
#  'Brian P. Schmidt',
#  'Carlos Filipe Ximenes Belo',
#  'Charles B. Huggins',
#  'Charles K. Kao',
#  'Charles K. Kao',
#  'Chen Ning Yang',
#  'Christian de Duve',
#  'Czesław Miłosz',
#  'Czesław Miłosz',
#  'César Milstein',
#  'Daniel Bovet',
#  'Daniel C. Tsui',
#  'Daniel Kahneman',
#  'David H. Hubel',
#  'David Trimble',
#  'Edmond H. Fischer',
#  'Ei-ichi Negishi',
#  'Elias Canetti',
#  'Elie Wiesel',
#  'Eric R. Kandel',
#  'Ernest Rutherford',
#  'Ernest Rutherford',
#  'Ernst Boris Chain',
#  'Eugene Wigner',
#  'Felix Bloch',
#  'Franco Modigliani',
# ...

# %%
df[df.duplicated('name')].count()
# Out:
# name              156
# category          155
# country            83
# date_of_birth     155
# date_of_death      95
# gender            152
# link              156
# place_of_birth    153
# place_of_death     90
# text              156
# year              156
# dtype: int64

# %%
df[df.duplicated('name')].sort_values(['name'], ascending = [1])
# Out:
#                           name   category         country     date_of_birth  \
# 121                 Aaron Klug  Chemistry    South Africa    11 August 1926
# 131                 Aaron Klug  Chemistry  United Kingdom    11 August 1926
# 742            Alan MacDiarmid  Chemistry             NaN     14 April 1927
# 844            Albert Einstein    Physics         Germany        1879-03-14
# 870          Albert Schweitzer      Peace             NaN   14 January 1875
# ...                        ...        ...             ...               ...
# 987            William Giauque  Chemistry             NaN      May 12, 1895
# 1035    William Lawrence Bragg    Physics             NaN     31 March 1890
# 1001           William Vickrey  Economics             NaN      21 June 1914
# 773             Yoichiro Nambu    Physics           Japan  January 18, 1921
# 1010  Zhores Ivanovich Alferov    Physics             NaN        1930-03-15
#
#          date_of_death gender  \
# ...

# %%
dups_name = df[df.duplicated('name')]['name']
df[df['name'].isin(dups_name)].sort_values(['name'], ascending = [1])
# Out:
#                           name   category         country     date_of_birth  \
# 131                 Aaron Klug  Chemistry  United Kingdom    11 August 1926
# 121                 Aaron Klug  Chemistry    South Africa    11 August 1926
# 106                 Aaron Klug  Chemistry             NaN    11 August 1926
# 440            Alan MacDiarmid  Chemistry   United States     14 April 1927
# 742            Alan MacDiarmid  Chemistry             NaN     14 April 1927
# ...                        ...        ...             ...               ...
# 417            William Vickrey  Economics   United States      21 June 1914
# 489             Yoichiro Nambu    Physics   United States  January 18, 1921
# 773             Yoichiro Nambu    Physics           Japan  January 18, 1921
# 1010  Zhores Ivanovich Alferov    Physics             NaN        1930-03-15
# 692   Zhores Ivanovich Alferov    Physics          Russia        1930-03-15
#
#         date_of_death gender  \
# ...

# %%
df['name']
# Out:
# 0                        César Milstein
# 1                            Ivo Andric
# 2                       Vladimir Prelog
# 3       Institut de Droit International
# 4                     Auguste Beernaert
#                      ...
# 1047                   Brian P. Schmidt
# 1048              Carlos Saavedra Lamas
# 1049                   Bernardo Houssay
# 1050               Luis Federico Leloir
# 1051              Adolfo Pérez Esquivel
# Name: name, Length: 1052, dtype: object

# %%
df[df.duplicated('name')]['name']
# Out:
# 90              Menachem Begin
# 91                Shimon Peres
# 109            Wilhelm Ostwald
# 121                 Aaron Klug
# 131                 Aaron Klug
#                  ...
# 1039    Aleksandr M. Prokhorov
# 1040             Patrick White
# 1042             John Harsanyi
# 1047          Brian P. Schmidt
# 1050      Luis Federico Leloir
# Name: name, Length: 156, dtype: object

# %%
sorted(list(df[df['name'].isin(df[df.duplicated('name')]['name'])]['name']))
# Out:
# ['Aaron Klug',
#  'Aaron Klug',
#  'Aaron Klug',
#  'Alan MacDiarmid',
#  'Alan MacDiarmid',
#  'Albert Einstein',
#  'Albert Einstein',
#  'Albert Schweitzer',
#  'Albert Schweitzer',
#  'Aleksandr M. Prokhorov',
#  'Aleksandr M. Prokhorov',
#  'Alexei A. Abrikosov',
#  'Alexei A. Abrikosov',
#  'Alfred Werner',
#  'Alfred Werner',
#  'Allan M. Cormack',
#  'Allan M. Cormack',
#  'Andre Geim',
#  'Andre Geim',
#  'Andrew Schally',
#  'Andrew Schally',
#  'Anthony J. Leggett',
#  'Anthony J. Leggett',
#  'Arieh Warshel',
#  'Arieh Warshel',
#  'Arno Penzias',
#  'Arno Penzias',
#  'Avram Hershko',
#  'Avram Hershko',
#  'Baruj Benacerraf',
#  'Baruj Benacerraf',
#  'Bernard Katz',
#  'Bernard Katz',
#  'Bertha von Suttner',
#  'Bertha von Suttner',
#  'Betty Williams',
#  'Betty Williams',
#  'Brian P. Schmidt',
#  'Brian P. Schmidt',
#  'Carlos Filipe Ximenes Belo',
#  'Carlos Filipe Ximenes Belo',
#  'Charles B. Huggins',
#  'Charles B. Huggins',
#  'Charles K. Kao',
# ...

# %%
df[df['name'].isin(df[df.duplicated('name')]['name'])].sort_values(['name'], ascending = 1) # 只有重複名字的df
# Out:
#                           name   category         country     date_of_birth  \
# 131                 Aaron Klug  Chemistry  United Kingdom    11 August 1926
# 121                 Aaron Klug  Chemistry    South Africa    11 August 1926
# 106                 Aaron Klug  Chemistry             NaN    11 August 1926
# 440            Alan MacDiarmid  Chemistry   United States     14 April 1927
# 742            Alan MacDiarmid  Chemistry             NaN     14 April 1927
# ...                        ...        ...             ...               ...
# 417            William Vickrey  Economics   United States      21 June 1914
# 489             Yoichiro Nambu    Physics   United States  January 18, 1921
# 773             Yoichiro Nambu    Physics           Japan  January 18, 1921
# 1010  Zhores Ivanovich Alferov    Physics             NaN        1930-03-15
# 692   Zhores Ivanovich Alferov    Physics          Russia        1930-03-15
#
#         date_of_death gender  \
# ...

# %%
df[df['name'].isin(df[df.duplicated('name')]['name'])].groupby('name')['name'].count()
# Out:
# pandas.core.series.Series

# %%
df[df['name'].isin(df[df.duplicated('name')]['name'])].sort_values(['name'], ascending = [1])['name', ]
# Out:
# 131                   Aaron Klug
# 121                   Aaron Klug
# 106                   Aaron Klug
# 440              Alan MacDiarmid
# 742              Alan MacDiarmid
#                   ...
# 417              William Vickrey
# 489               Yoichiro Nambu
# 773               Yoichiro Nambu
# 1010    Zhores Ivanovich Alferov
# 692     Zhores Ivanovich Alferov
# Name: name, Length: 299, dtype: object

# %%
df[df.duplicated(['name', 'category', 'year'])][['name', 'category', 'year']]
# Out:
#                         name    category  year
# 90            Menachem Begin       Peace  1978
# 91              Shimon Peres       Peace  1994
# 109          Wilhelm Ostwald   Chemistry  1909
# 121               Aaron Klug   Chemistry  1982
# 131               Aaron Klug   Chemistry  1982
# ...                      ...         ...   ...
# 1039  Aleksandr M. Prokhorov     Physics  1964
# 1040           Patrick White  Literature  1973
# 1042           John Harsanyi   Economics  1994
# 1047        Brian P. Schmidt     Physics  2011
# 1050    Luis Federico Leloir   Chemistry  1970
#
# [147 rows x 3 columns]

# %%
df = df.reindex(np.random.permutation(df.index))
df = df.drop_duplicates(['name', 'category', 'year'])
df = df.sort_index()
df.count()
# Out:
# name              900
# category          901
# country           818
# date_of_birth     892
# date_of_death     590
# gender            893
# link              900
# place_of_birth    866
# place_of_death    548
# text              900
# year              900
# dtype: int64

# %%
df[df['name'].isin(df[df.duplicated('name')]['name'])].sort_values(['name'], ascending = [1])
#Andrew Schally
#Ragnar Granit
#Sidney Altman
#Robert Bárány
# Out:
#                         name                category         country  \
# 104           Andrew Schally                     NaN             NaN
# 712           Andrew Schally                     NaN             NaN
# 548         Frederick Sanger               Chemistry  United Kingdom
# 580         Frederick Sanger               Chemistry  United Kingdom
# 292             John Bardeen                 Physics   United States
# 326             John Bardeen                 Physics   United States
# 285         Linus C. Pauling               Chemistry   United States
# 309         Linus C. Pauling                   Peace   United States
# 919              Marie Curie               Chemistry          France
# 910              Marie Curie                 Physics          France
# 706   Marie Skłodowska-Curie                 Physics          Poland
# 709   Marie Skłodowska-Curie               Chemistry          Poland
# 960            Ragnar Granit  Physiology or Medicine         Finland
# ...

# %%
df[df['name'].isin(['Andrew Schally','Ragnar Granit','Sidney Altman','Robert Bárány'])]
# Out:
#                 name                category        country  \
# 104   Andrew Schally                     NaN            NaN
# 396    Sidney Altman               Chemistry  United States
# 650    Ragnar Granit  Physiology or Medicine         Sweden
# 712   Andrew Schally                     NaN            NaN
# 820    Robert Bárány                     NaN            NaN
# 960    Ragnar Granit  Physiology or Medicine        Finland
# 995    Sidney Altman               Chemistry         Canada
# 1016   Robert Bárány  Physiology or Medicine        Austria
#
#           date_of_birth   date_of_death gender  \
# 104   November 30, 1926             NaN   male
# 396         May 7, 1939             NaN   male
# 650    October 30, 1900  March 12, 1991   None
# 712   November 30, 1926             NaN   male
# 820       22 April 1876    8 April 1936   male
# 960    October 30, 1900  March 12, 1991   None
# 995         May 7, 1939             NaN   male
# ...

# %%
df[df['name'] == 'Marie Skłodowska-Curie']
# Out:
# Empty DataFrame
# Columns: [name, category, country, date_of_birth, date_of_death, gender, link, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df[df['name'] == 'Marie Skłodowska-Curie']
# df = df.set_index('name')
# df.loc['Marie Skłodowska-Curie', 'name']
# df = df.reset_index()
df.loc[706, 'name'] = 'Marie Curie'
df.loc[709, 'name'] = 'Marie Curie'
df[df['name'] == 'Marie Skłodowska-Curie']
# Out:
# Empty DataFrame
# Columns: [name, category, country, date_of_birth, date_of_death, gender, link, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df.loc[820, 'category'] = 'Physiology or Medicine'
df.loc[369, 'year'] = 1989
df.loc[960, 'year'] = 1967
df.loc[712, 'year'] = 1977
df.loc[104, 'category'] = 'Physiology or Medicine'
df.loc[712, 'category'] = 'Physiology or Medicine'
df[df['name'].isin(['Andrew Schally','Ragnar Granit','Sidney Altman','Robert Bárány'])]
#list(df.index[df['name'] == 'Andrew Schally']) # index = 712
# Out:
#                name                category        country      date_of_birth  \
# 396   Sidney Altman               Chemistry  United States        May 7, 1939
# 712  Andrew Schally  Physiology or Medicine            NaN  November 30, 1926
# 820   Robert Bárány  Physiology or Medicine            NaN      22 April 1876
# 960   Ragnar Granit  Physiology or Medicine        Finland   October 30, 1900
# 995   Sidney Altman               Chemistry         Canada        May 7, 1939
#
#       date_of_death gender                                               link  \
# 396             NaN   male         http://en.wikipedia.org/wiki/Sidney_Altman
# 712             NaN   male        http://en.wikipedia.org/wiki/Andrew_Schally
# 820    8 April 1936   male  http://en.wikipedia.org/wiki/Robert_B%C3%A1r%C...
# 960  March 12, 1991   None         http://en.wikipedia.org/wiki/Ragnar_Granit
# 995             NaN   male         http://en.wikipedia.org/wiki/Sidney_Altman
#
# ...

# %%
list(df.index[df['name'] == 'Andrew Schally'])
# Out:
# [712]

# %%
df[df['gender'] == 'None']
# Out:
# Empty DataFrame
# Columns: [name, category, country, date_of_birth, date_of_death, gender, link, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df.loc[650, 'gender'] = 'male'
df.loc[960, 'gender'] = 'male'
df[df.gender.isna()]
# Out:
#                                                    name  \
# 3                       Institut de Droit International
# 156                             Friends Service Council
# 267   American Friends Service Committee  (The Quakers)
# 574                               Amnesty International
# 696                                Konstantin Novoselov
# 947                            Médecins Sans Frontières
# 1000   Pugwash Conferences on Science and World Affairs
# 1033                 International Atomic Energy Agency
# 104                                                 NaN
#
#                     category         country   date_of_birth date_of_death  \
# 3                      Peace         Belgium            None          None
# 156                    Peace  United Kingdom            None          None
# 267                    Peace   United States            None          None
# 574                    Peace  United Kingdom            None          None
# ...

# %%
df[df['category'].isna()]
df.loc[812,'category'] = 'Physiology or Medicine'
df.loc[815,'category'] = 'Economics'
df.loc[922,'category'] = 'Physiology or Medicine'
df[df['category'].isna()]
df.loc[958,'year'] = 1939
df.loc[959,'year'] = 1945
df[df.year == 1809]
# Out:
# Empty DataFrame
# Columns: [name, category, country, date_of_birth, date_of_death, gender, link, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], errors = 'raise')
df['date_of_birth']
# Out:
# 0      1927-10-08
# 1      1892-10-09
# 3             NaT
# 4      1829-07-26
# 5      1862-08-29
#           ...
# 1045   1951-09-30
# 1046   1948-11-26
# 1048   1878-11-01
# 1049   1887-04-10
# 1051   1931-11-26
# Name: date_of_birth, Length: 902, dtype: datetime64[ns]

# %%
pd.to_datetime(df['date_of_death'], errors = 'raise')
# df[df['date_of_death'] == '1968-23-07']
# list(df.index[df['date_of_death'] == '1968-23-07'])
# df.loc[list(df.index[df['date_of_death'] == '1968-23-07']), 'date_of_death'] = '1968-07-23'
# df.loc[list(df.index[df['date_of_death'] == 'May 30, 2011 (aged 89)']), 'date_of_death'] = 'May 30, 2011'
# df.loc[list(df.index[df['date_of_death'] == 'np.nan']), 'date_of_death'] = np.nan
# df.loc[list(df.index[df['date_of_death'] == 'Diederik Korteweg']), 'date_of_death'] = '1923-03-08'
# df.loc[list(df.index[df['date_of_death'] == '1 February 1976, age 74']), 'date_of_death'] = '1976-02-01'
# Out:
# 0      2002-03-24
# 1      1975-03-13
# 3             NaT
# 4      1912-10-06
# 5      1949-05-06
#           ...
# 1045          NaT
# 1046          NaT
# 1048   1959-05-05
# 1049   1971-09-21
# 1051          NaT
# Name: date_of_death, Length: 902, dtype: datetime64[ns]

# %%
df.iloc[[5,815],[1,2]]
# Out:
#       category  country
# 6        Peace  Belgium
# 935  Chemistry      NaN
