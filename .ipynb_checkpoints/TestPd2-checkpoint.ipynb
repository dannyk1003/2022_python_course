# %%
import pandas as pd
df = pd.read_json('nobel_winners.json')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         1052 non-null   object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1044 non-null   object
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %%
df.describe()
# Out:
#               year
# count  1052.000000
# mean   1968.729087
# std      33.155829
# min    1809.000000
# 25%    1947.000000
# 50%    1975.000000
# 75%    1996.000000
# max    2014.000000

# %%
df.describe(include='object')
# Out:
#        born_in                category        country date_of_birth  \
# count     1052                    1052           1052          1044
# unique      40                       7             59           853
# top             Physiology or Medicine  United States    9 May 1947
# freq       910                     250            350             4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                   name place_of_birth place_of_death  \
# count             1052           1044           1044
# unique             998            735            410
# top     Sydney Brenner
# freq                 2             29            409
#
# ...

# %%
df.describe(include='all')
# Out:
#        born_in                category        country date_of_birth  \
# count     1052                    1052           1052          1044
# unique      40                       7             59           853
# top             Physiology or Medicine  United States    9 May 1947
# freq       910                     250            350             4
# mean       NaN                     NaN            NaN           NaN
# std        NaN                     NaN            NaN           NaN
# min        NaN                     NaN            NaN           NaN
# 25%        NaN                     NaN            NaN           NaN
# 50%        NaN                     NaN            NaN           NaN
# 75%        NaN                     NaN            NaN           NaN
# max        NaN                     NaN            NaN           NaN
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# ...

# %%
#print(type(df.columns))
#print(type(df.describe))
df.columns
# Out:
# Index(['born_in', 'category', 'country', 'date_of_birth', 'date_of_death',
#        'gender', 'link', 'name', 'place_of_birth', 'place_of_death', 'text',
#        'year'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1052, step=1)

# %%
df
# Out:
#                      born_in                category    country  \
# 0                             Physiology or Medicine  Argentina
# 1     Bosnia and Herzegovina              Literature
# 2     Bosnia and Herzegovina               Chemistry
# 3                                              Peace    Belgium
# 4                                              Peace    Belgium
# ...                      ...                     ...        ...
# 1047                                         Physics  Australia
# 1048                                           Peace  Argentina
# 1049                          Physiology or Medicine  Argentina
# 1050                                       Chemistry  Argentina
# 1051                                           Peace  Argentina
#
#           date_of_birth   date_of_death gender  \
# 0        8 October 1927   24 March 2002   male
# 1        9 October 1892   13 March 1975   male
# 2         July 23, 1906      1998-01-07   male
# ...

# %%
df = df.set_index('name')           #寫回df，才能變更index為name欄位
#df.set_index('name',inplace=True)    #透過inplace設定，將index異動為name欄位
df
#df.set_index('name')
# Out:
#                                                 born_in  \
# name
# César Milstein
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International
# Auguste Beernaert
# ...                                                 ...
# Brian P. Schmidt
# Carlos Saavedra Lamas
# Bernardo Houssay
# Luis Federico Leloir
# Adolfo Pérez Esquivel
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature
# Vladimir Prelog *                             Chemistry
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
# ...                                                 ...        ...
# Brian P. Schmidt                                Physics  Australia
# ...

# %%
df.loc[['César Milstein','Auguste Beernaert'],['category','country']]  #使用名稱去叫用資料，df.loc[index,columns]
#SELECT category,country FROM nobels WHERE name = "César Milstein"
# Out:
#                                  category         country
# name
# César Milstein     Physiology or Medicine       Argentina
# César Milstein     Physiology or Medicine  United Kingdom
# Auguste Beernaert                   Peace         Belgium

# %%
df.iloc[[0,4],[1,2]]  #使用位置址去叫用資料，df.iloc[列位置,欄位置]
# Out:
#                                  category    country
# name
# César Milstein     Physiology or Medicine  Argentina
# Auguste Beernaert                   Peace    Belgium

# %%
df = df.reset_index()

# %%
df[['name','category','year']]
# Out:
#                                  name                category  year
# 0                      César Milstein  Physiology or Medicine  1984
# 1                        Ivo Andric *              Literature  1961
# 2                   Vladimir Prelog *               Chemistry  1975
# 3     Institut de Droit International                   Peace  1904
# 4                   Auguste Beernaert                   Peace  1909
# ...                               ...                     ...   ...
# 1047                 Brian P. Schmidt                 Physics  2011
# 1048            Carlos Saavedra Lamas                   Peace  1936
# 1049                 Bernardo Houssay  Physiology or Medicine  1947
# 1050             Luis Federico Leloir               Chemistry  1970
# 1051            Adolfo Pérez Esquivel                   Peace  1980
#
# [1052 rows x 3 columns]

# %%
df.year
# Out:
# 0       1984
# 1       1961
# 2       1975
# 3       1904
# 4       1909
#         ...
# 1047    2011
# 1048    1936
# 1049    1947
# 1050    1970
# 1051    1980
# Name: year, Length: 1052, dtype: int64

# %%
df.loc[:,'year']
# Out:
# 0       1984
# 1       1961
# 2       1975
# 3       1904
# 4       1909
#         ...
# 1047    2011
# 1048    1936
# 1049    1947
# 1050    1970
# 1051    1980
# Name: year, Length: 1052, dtype: int64

# %%
mask = df.year > 2000
df[mask].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 13 to 1047
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         202 non-null    object
#  1   category        202 non-null    object
#  2   country         202 non-null    object
#  3   date_of_birth   201 non-null    object
#  4   date_of_death   201 non-null    object
#  5   gender          200 non-null    object
#  6   link            202 non-null    object
#  7   name            202 non-null    object
#  8   place_of_birth  201 non-null    object
#  9   place_of_death  201 non-null    object
#  10  text            202 non-null    object
#  11  year            202 non-null    int64
# dtypes: int64(1), object(11)
# memory usage: 20.5+ KB

# %%
df[mask][['name','category','year']]
# Out:
#                            name                category  year
# 13             François Englert                 Physics  2013
# 32    Christopher A. Pissarides               Economics  2010
# 66                   Kofi Annan                   Peace  2001
# 87          Riccardo Giacconi *                 Physics  2002
# 88             Mario Capecchi *  Physiology or Medicine  2007
# ...                         ...                     ...   ...
# 1034           Martin Karplus *               Chemistry  2013
# 1044            J. Robin Warren  Physiology or Medicine  2005
# 1045             Barry Marshall  Physiology or Medicine  2005
# 1046   Elizabeth H. Blackburn *  Physiology or Medicine  2009
# 1047           Brian P. Schmidt                 Physics  2011
#
# [202 rows x 3 columns]

# %%
df['born_in'][df.born_in != ''] #df.born_in
# Out:
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 14                     Belarus
# 15                     Belarus
# 16                     Belarus
#                  ...
# 1034                   Austria
# 1035                 Australia
# 1039                 Australia
# 1041                 Australia
# 1046                 Australia
# Name: born_in, Length: 142, dtype: object

# %%
df_born_in = df[df.born_in != '']
df_born_in
# Out:
#                      born_in                category country  \
# 1     Bosnia and Herzegovina              Literature
# 2     Bosnia and Herzegovina               Chemistry
# 14                   Belarus               Economics
# 15                   Belarus                   Peace
# 16                   Belarus                   Peace
# ...                      ...                     ...     ...
# 1034                 Austria               Chemistry
# 1035               Australia                 Physics
# 1039               Australia                 Physics
# 1041               Australia               Chemistry
# 1046               Australia  Physiology or Medicine
#
#          date_of_birth    date_of_death  gender  \
# 1       9 October 1892    13 March 1975    male
# 2        July 23, 1906       1998-01-07    male
# 14      April 30, 1901     July 8, 1985    male
# 15      16 August 1913     9 March 1992    male
# 16       2 August 1923                     male
# ...

# %%
import numpy as np
df['born_in'] = df['born_in'].replace('',np.nan)

# %%
df['born_in']
# Out:
# 0                          NaN
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3                          NaN
# 4                          NaN
#                  ...
# 1047                       NaN
# 1048                       NaN
# 1049                       NaN
# 1050                       NaN
# 1051                       NaN
# Name: born_in, Length: 1052, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         142 non-null    object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1044 non-null   object
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %%
df = df.drop('born_in',axis=1)
df
# Out:
#                     category    country      date_of_birth   date_of_death  \
# 0     Physiology or Medicine  Argentina     8 October 1927   24 March 2002
# 1                 Literature                9 October 1892   13 March 1975
# 2                  Chemistry                 July 23, 1906      1998-01-07
# 3                      Peace    Belgium               None            None
# 4                      Peace    Belgium       26 July 1829  6 October 1912
# ...                      ...        ...                ...             ...
# 1047                 Physics  Australia  February 24, 1967
# 1048                   Peace  Argentina   November 1, 1878     May 5, 1959
# 1049  Physiology or Medicine  Argentina         1887-04-10      1971-09-21
# 1050               Chemistry  Argentina           1906-9-6       1987-12-2
# 1051                   Peace  Argentina  November 26, 1931
#
#      gender                                               link  \
# ...

# %%
#import numpy as np
df = df.replace('',np.nan)
df
# Out:
#                     category    country      date_of_birth   date_of_death  \
# 0     Physiology or Medicine  Argentina     8 October 1927   24 March 2002
# 1                 Literature        NaN     9 October 1892   13 March 1975
# 2                  Chemistry        NaN      July 23, 1906      1998-01-07
# 3                      Peace    Belgium               None            None
# 4                      Peace    Belgium       26 July 1829  6 October 1912
# ...                      ...        ...                ...             ...
# 1047                 Physics  Australia  February 24, 1967             NaN
# 1048                   Peace  Argentina   November 1, 1878     May 5, 1959
# 1049  Physiology or Medicine  Argentina         1887-04-10      1971-09-21
# 1050               Chemistry  Argentina           1906-9-6       1987-12-2
# 1051                   Peace  Argentina  November 26, 1931             NaN
#
#      gender                                               link  \
# ...

# %%
#df[df.country.isna()]
#df[df.gender.isna()]
df[df.place_of_death.isna()]
# Out:
#                     category    country      date_of_birth  \
# 3                      Peace    Belgium               None
# 7     Physiology or Medicine    Belgium       13 June 1870
# 13                   Physics    Belgium    6 November 1932
# 16                     Peace        NaN      2 August 1923
# 18    Physiology or Medicine    Denmark  November 15, 1874
# ...                      ...        ...                ...
# 1044  Physiology or Medicine  Australia       11 June 1937
# 1045  Physiology or Medicine  Australia  30 September 1951
# 1046  Physiology or Medicine        NaN         1948-11-26
# 1047                 Physics  Australia  February 24, 1967
# 1051                   Peace  Argentina  November 26, 1931
#
#            date_of_death  gender  \
# 3                   None    None
# 7           6 April 1961    male
# 13                   NaN    male
# 16                   NaN    male
# 18    September 13, 1949    male
# ...                  ...     ...
# ...

# %%
df[df.name.str.contains('\*')]
# Out:
#                     category country     date_of_birth    date_of_death  \
# 1                 Literature     NaN    9 October 1892    13 March 1975
# 2                  Chemistry     NaN     July 23, 1906       1998-01-07
# 14                 Economics     NaN    April 30, 1901     July 8, 1985
# 15                     Peace     NaN    16 August 1913     9 March 1992
# 16                     Peace     NaN     2 August 1923              NaN
# ...                      ...     ...               ...              ...
# 1034               Chemistry     NaN    March 15, 1930              NaN
# 1035                 Physics     NaN     31 March 1890      1 July 1971
# 1039                 Physics     NaN      11 July 1916   8 January 2002
# 1041               Chemistry     NaN  7 September 1917  8 December 2013
# 1046  Physiology or Medicine     NaN        1948-11-26              NaN
#
#       gender                                               link  \
# ...

# %%
#df['born_in'].replace('',np.nan)  #整個欄位符合條件就完整取代
df['name'] = df['name'].str.replace('*','')    #部分文字符合條件就取代部分文字
df['name'] = df['name'].str.strip()
df['name']
# Out:
# 0                        César Milstein
# 1                            Ivo Andric
# 2                       Vladimir Prelog
# 3       Institut de Droit International
# 4                     Auguste Beernaert
#                      ...
# 1047                   Brian P. Schmidt
# 1048              Carlos Saavedra Lamas
# 1049                   Bernardo Houssay
# 1050               Luis Federico Leloir
# 1051              Adolfo Pérez Esquivel
# Name: name, Length: 1052, dtype: object

# %%
mask = df.duplicated('name')
sorted(list(df[mask]['name']))
# Out:
# ['Aaron Klug',
#  'Aaron Klug',
#  'Alan MacDiarmid',
#  'Albert Einstein',
#  'Albert Schweitzer',
#  'Aleksandr M. Prokhorov',
#  'Alexei A. Abrikosov',
#  'Alfred Werner',
#  'Allan M. Cormack',
#  'Andre Geim',
#  'Andrew Schally',
#  'Anthony J. Leggett',
#  'Arieh Warshel',
#  'Arno Penzias',
#  'Avram Hershko',
#  'Baruj Benacerraf',
#  'Bernard Katz',
#  'Bertha von Suttner',
#  'Betty Williams',
#  'Brian P. Schmidt',
#  'Carlos Filipe Ximenes Belo',
#  'Charles B. Huggins',
#  'Charles K. Kao',
#  'Charles K. Kao',
#  'Chen Ning Yang',
#  'Christian de Duve',
#  'Czesław Miłosz',
#  'Czesław Miłosz',
#  'César Milstein',
#  'Daniel Bovet',
#  'Daniel C. Tsui',
#  'Daniel Kahneman',
#  'David H. Hubel',
#  'David Trimble',
#  'Edmond H. Fischer',
#  'Ei-ichi Negishi',
#  'Elias Canetti',
#  'Elie Wiesel',
#  'Eric R. Kandel',
#  'Ernest Rutherford',
#  'Ernest Rutherford',
#  'Ernst Boris Chain',
#  'Eugene Wigner',
#  'Felix Bloch',
#  'Franco Modigliani',
# ...

# %%
df[df.duplicated('name')].count()
# Out:
# name              5
# category          5
# country           5
# date_of_birth     5
# date_of_death     4
# gender            6
# link              5
# place_of_birth    5
# place_of_death    4
# text              5
# year              5
# award_age         6
# First_Name        5
# Last_Name         5
# Middle_Name       5
# dtype: int64

# %%
mask = df.duplicated('name')
df[mask].sort_values(['name'],ascending=[1])
# Out:
#        category         country     date_of_birth     date_of_death gender  \
# 121   Chemistry    South Africa    11 August 1926               NaN   male
# 131   Chemistry  United Kingdom    11 August 1926               NaN   male
# 742   Chemistry             NaN     14 April 1927   7 February 2007   male
# 844     Physics         Germany        1879-03-14        1955-04-18   male
# 870       Peace             NaN   14 January 1875  4 September 1965   male
# ...         ...             ...               ...               ...    ...
# 987   Chemistry             NaN      May 12, 1895    March 28, 1982   male
# 1035    Physics             NaN     31 March 1890       1 July 1971   male
# 1001  Economics             NaN      21 June 1914   11 October 1996   male
# 773     Physics           Japan  January 18, 1921               NaN   male
# 1010    Physics             NaN        1930-03-15               NaN   male
#
#                                                    link  \
# ...

# %%
mask = df.duplicated('name')
dupes_name = df[mask]['name']
df[df.name.isin(dupes_name)].sort_values(['name'],ascending=[1])
# Out:
#        category         country     date_of_birth    date_of_death gender  \
# 131   Chemistry  United Kingdom    11 August 1926              NaN   male
# 121   Chemistry    South Africa    11 August 1926              NaN   male
# 106   Chemistry             NaN    11 August 1926              NaN   male
# 440   Chemistry   United States     14 April 1927  7 February 2007   male
# 742   Chemistry             NaN     14 April 1927  7 February 2007   male
# ...         ...             ...               ...              ...    ...
# 417   Economics   United States      21 June 1914  11 October 1996   male
# 489     Physics   United States  January 18, 1921              NaN   male
# 773     Physics           Japan  January 18, 1921              NaN   male
# 1010    Physics             NaN        1930-03-15              NaN   male
# 692     Physics          Russia        1930-03-15              NaN   male
#
#                                                    link  \
# ...

# %%
sorted(list(df[df.name.isin(dupes_name)]['name']))
#len(sorted(list(df[df.name.isin(dupes_name)]['name'])))
# Out:
# ['Aaron Klug',
#  'Aaron Klug',
#  'Aaron Klug',
#  'Alan MacDiarmid',
#  'Alan MacDiarmid',
#  'Albert Einstein',
#  'Albert Einstein',
#  'Albert Schweitzer',
#  'Albert Schweitzer',
#  'Aleksandr M. Prokhorov',
#  'Aleksandr M. Prokhorov',
#  'Alexei A. Abrikosov',
#  'Alexei A. Abrikosov',
#  'Alfred Werner',
#  'Alfred Werner',
#  'Allan M. Cormack',
#  'Allan M. Cormack',
#  'Andre Geim',
#  'Andre Geim',
#  'Andrew Schally',
#  'Andrew Schally',
#  'Anthony J. Leggett',
#  'Anthony J. Leggett',
#  'Arieh Warshel',
#  'Arieh Warshel',
#  'Arno Penzias',
#  'Arno Penzias',
#  'Avram Hershko',
#  'Avram Hershko',
#  'Baruj Benacerraf',
#  'Baruj Benacerraf',
#  'Bernard Katz',
#  'Bernard Katz',
#  'Bertha von Suttner',
#  'Bertha von Suttner',
#  'Betty Williams',
#  'Betty Williams',
#  'Brian P. Schmidt',
#  'Brian P. Schmidt',
#  'Carlos Filipe Ximenes Belo',
#  'Carlos Filipe Ximenes Belo',
#  'Charles B. Huggins',
#  'Charles B. Huggins',
#  'Charles K. Kao',
# ...

# %%
df[df.name.isin(dupes_name)].groupby('name').name.count()
# Out:
# name
# Aaron Klug                  3
# Alan MacDiarmid             2
# Albert Einstein             2
# Albert Schweitzer           2
# Aleksandr M. Prokhorov      2
#                            ..
# William Giauque             2
# William Lawrence Bragg      2
# William Vickrey             2
# Yoichiro Nambu              2
# Zhores Ivanovich Alferov    2
# Name: name, Length: 143, dtype: int64

# %%
mask = df.duplicated('name')
dupes_name = df[mask]['name']
(df[df.name.isin(dupes_name)].sort_values(['name'],ascending=[1]))['name']
# Out:
# 131                   Aaron Klug
# 121                   Aaron Klug
# 106                   Aaron Klug
# 440              Alan MacDiarmid
# 742              Alan MacDiarmid
#                   ...
# 417              William Vickrey
# 489               Yoichiro Nambu
# 773               Yoichiro Nambu
# 1010    Zhores Ivanovich Alferov
# 692     Zhores Ivanovich Alferov
# Name: name, Length: 299, dtype: object

# %%
df[df.duplicated(['name','category','year'])][['name','category','year']]
# Out:
#                         name    category  year
# 90            Menachem Begin       Peace  1978
# 91              Shimon Peres       Peace  1994
# 109          Wilhelm Ostwald   Chemistry  1909
# 121               Aaron Klug   Chemistry  1982
# 131               Aaron Klug   Chemistry  1982
# ...                      ...         ...   ...
# 1039  Aleksandr M. Prokhorov     Physics  1964
# 1040           Patrick White  Literature  1973
# 1042           John Harsanyi   Economics  1994
# 1047        Brian P. Schmidt     Physics  2011
# 1050    Luis Federico Leloir   Chemistry  1970
#
# [147 rows x 3 columns]

# %%
df[df.duplicated(['name'])][['name','category','year']]
# Out:
#                         name    category  year
# 90            Menachem Begin       Peace  1978
# 91              Shimon Peres       Peace  1994
# 109          Wilhelm Ostwald   Chemistry  1909
# 121               Aaron Klug   Chemistry  1982
# 131               Aaron Klug   Chemistry  1982
# ...                      ...         ...   ...
# 1039  Aleksandr M. Prokhorov     Physics  1964
# 1040           Patrick White  Literature  1973
# 1042           John Harsanyi   Economics  1994
# 1047        Brian P. Schmidt     Physics  2011
# 1050    Luis Federico Leloir   Chemistry  1970
#
# [156 rows x 3 columns]

# %%
df = df.reindex(np.random.permutation(df.index))
df = df.drop_duplicates(['name','category','year'])
df = df.sort_index()
df.count()
# Out:
# category          899
# country           815
# date_of_birth     897
# date_of_death     594
# gender            896
# link              905
# name              905
# place_of_birth    871
# place_of_death    552
# text              905
# year              905
# dtype: int64

# %%
df[df.duplicated(['name'])][['name','category','year']]
#Andrew Schally
#Ragnar Granit
#Sidney Altman
#Robert Bárány
# Out:
#                         name                category  year
# 309         Linus C. Pauling                   Peace  1962
# 326             John Bardeen                 Physics  1972
# 580         Frederick Sanger               Chemistry  1980
# 709   Marie Skłodowska-Curie               Chemistry  1911
# 712           Andrew Schally                     NaN  1976
# 919              Marie Curie               Chemistry  1911
# 960            Ragnar Granit  Physiology or Medicine  1809
# 995            Sidney Altman               Chemistry  1989
# 1016           Robert Bárány  Physiology or Medicine  1914

# %%
df.loc[820,'category'] = 'Physiology or Medicine'
df.loc[396,'year'] = 1989
df.loc[960,'year'] = 1967
df.loc[712,'year'] = 1977
df.loc[712,'category'] = 'Physiology or Medicine'
df.loc[104,'category'] = 'Physiology or Medicine'
df[df.name.isin(['Andrew Schally','Ragnar Granit','Sidney Altman','Robert Bárány'])]
# Out:
#                     category        country      date_of_birth  \
# 104   Physiology or Medicine            NaN  November 30, 1926
# 396                Chemistry  United States        May 7, 1939
# 650   Physiology or Medicine         Sweden   October 30, 1900
# 712   Physiology or Medicine            NaN  November 30, 1926
# 820   Physiology or Medicine            NaN      22 April 1876
# 960   Physiology or Medicine        Finland   October 30, 1900
# 995                Chemistry         Canada        May 7, 1939
# 1016  Physiology or Medicine        Austria      22 April 1876
#
#        date_of_death gender  \
# 104              NaN   male
# 396              NaN   male
# 650   March 12, 1991   None
# 712              NaN   male
# 820     8 April 1936   male
# 960   March 12, 1991   None
# 995              NaN   male
# 1016    8 April 1936   male
#
#                                                    link            name  \
# ...

# %%
#706 709
df.loc[706,'name'] = 'Marie Curie'
df.loc[709,'name'] = 'Marie Curie'
df[df.name == 'Marie Skłodowska-Curie']
# Out:
# Empty DataFrame
# Columns: [category, country, date_of_birth, date_of_death, gender, link, name, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df.loc[650,'gender'] = 'male'
df.loc[960,'gender'] = 'male'
df[df.gender.isna()]
# Out:
#      category         country date_of_birth date_of_death gender  \
# 3       Peace         Belgium          None          None   None
# 156     Peace  United Kingdom          None          None   None
# 267     Peace   United States          None          None   None
# 574     Peace  United Kingdom          None          None   None
# 947     Peace          France          None          None   None
# 1000    Peace          Canada          None          None   None
# 1033    Peace         Austria          None          None   None
#
#                                                    link  \
# 3     http://en.wikipedia.org/wiki/Institut_de_Droit...
# 156   http://en.wikipedia.org/wiki/Friends_Service_C...
# 267   http://en.wikipedia.org/wiki/American_Friends_...
# 574   http://en.wikipedia.org/wiki/Amnesty_Internati...
# 947   http://en.wikipedia.org/wiki/M%C3%A9decins_San...
# 1000  http://en.wikipedia.org/wiki/Pugwash_Conferenc...
# ...

# %%
df.loc[812,'category'] = 'Physiology or Medicine'
df.loc[815,'category'] = 'Economics'
df.loc[922,'category'] = 'Physiology or Medicine'
df[df.category.isna()]
df.loc[958,'year'] = 1939
df.loc[959,'year'] = 1945
df[df.year == 1809]
# Out:
# Empty DataFrame
# Columns: [category, country, date_of_birth, date_of_death, gender, link, name, place_of_birth, place_of_death, text, year]
# Index: []

# %%
df.date_of_birth = pd.to_datetime(df.date_of_birth,errors='raise')
df.date_of_birth
# Out:
# 0      1927-10-08
# 1      1892-10-09
# 2      1906-07-23
# 3             NaT
# 4      1829-07-26
#           ...
# 1047   1967-02-24
# 1048   1878-11-01
# 1049   1887-04-10
# 1050   1906-09-06
# 1051   1931-11-26
# Name: date_of_birth, Length: 1052, dtype: datetime64[ns]

# %%
pd.to_datetime(df.date_of_death,errors='raise') #errors='coerce'

#df[df.date_of_death=='1968-23-07']
#df.loc[150,'date_of_death'] = '1968-07-23'

#df[df.date_of_death=='May 30, 2011 (aged 89)']
#df.loc[349,'date_of_death'] = '2011-05-30'

#df[df.date_of_death=='Diederik Korteweg']
#df.loc[746,'date_of_death'] = '1923-03-08'


#df.date_of_death = df.date_of_death.replace('living',np.nan)

#df[df.date_of_death=='1 February 1976, age 74']
#df.loc[858,'date_of_death'] = '1976-02-01'
# Out:
# 1      1975-03-13
# 3             NaT
# 4      1912-10-06
# 5      1949-05-06
# 6      1943-05-14
#           ...
# 1046          NaT
# 1047          NaT
# 1048   1959-05-05
# 1049   1971-09-21
# 1051          NaT
# Name: date_of_death, Length: 905, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 905 entries, 1 to 1051
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        905 non-null    object
#  1   country         815 non-null    object
#  2   date_of_birth   897 non-null    datetime64[ns]
#  3   date_of_death   591 non-null    object
#  4   gender          898 non-null    object
#  5   link            905 non-null    object
#  6   name            905 non-null    object
#  7   place_of_birth  871 non-null    object
#  8   place_of_death  552 non-null    object
#  9   text            905 non-null    object
#  10  year            905 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 124.8+ KB

# %%
df['award_age'] = df.year - pd.DatetimeIndex(df.date_of_birth).year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         1052 non-null   object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1043 non-null   datetime64[ns]
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
#  12  award_age       1043 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 107.0+ KB

# %%
df[df.award_age<=30]
# Out:
#         born_in                category         country date_of_birth  \
# 525                             Physics  United Kingdom    1890-03-31
# 626              Physiology or Medicine     Switzerland    1946-04-17
# 725                               Peace        Pakistan    1997-07-12
# 958                          Literature         Finland    1888-09-16
# 959                           Chemistry         Finland    1895-01-15
# 960              Physiology or Medicine         Finland    1900-10-30
# 1035  Australia                 Physics                    1890-03-31
#
#          date_of_death  gender  \
# 525        1 July 1971    male
# 626      March 1, 1995    male
# 725                     female
# 958        3 June 1964    male
# 959   11 November 1973    male
# 960     March 12, 1991    None
# 1035       1 July 1971    male
#
#                                                    link  \
# 525   http://en.wikipedia.org/wiki/William_Lawrence_...
# ...

# %%
df.award_age = df.award_age.fillna(-99)
df.award_age = df.award_age.astype('int32')
#df.award_age = df.award_age.replace(-99,np.nan)
df.award_age
# Out:
# 0       57
# 1       69
# 2       69
# 3      -99
# 4       80
#         ..
# 1047    44
# 1048    58
# 1049    60
# 1050    64
# 1051    49
# Name: award_age, Length: 1052, dtype: int32

# %%
df['First_Name'] = df['name'].str.split(' ').str[0]
df['First_Name']
# Out:
# 0          César
# 1            Ivo
# 2       Vladimir
# 3       Institut
# 4        Auguste
#           ...
# 1047       Brian
# 1048      Carlos
# 1049    Bernardo
# 1050        Luis
# 1051      Adolfo
# Name: First_Name, Length: 1052, dtype: object

# %%
df['Last_Name'] = df['name'].str.split(' ').str[1:].str.join(' ')
df['Last_Name']
# Out:
# 0                     Milstein
# 1                     Andric *
# 2                     Prelog *
# 3       de Droit International
# 4                    Beernaert
#                  ...
# 1047                P. Schmidt
# 1048            Saavedra Lamas
# 1049                   Houssay
# 1050           Federico Leloir
# 1051            Pérez Esquivel
# Name: Last_Name, Length: 1052, dtype: object
